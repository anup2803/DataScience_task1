# %% [markdown]
# # Student performance

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("student_performance.csv")

# %%
df.head()
# Out:
#   Student_ID  Age  Gender  Study_Hours  Attendance(%)  Test_Score Grade
# 0      S0524   21  Female          2.7           74.0        37.0     F
# 1      S0603   19    Male          1.5           93.1        26.0     F
# 2      S0527   20  Female          6.8           97.2        88.0     A
# 3      S0032   18  Female          6.2           93.5        55.0     C
# 4      S0617   21    Male          7.4           99.2        77.0     B

# %%
df.shape
# Out:
# (1020, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1020 entries, 0 to 1019
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Student_ID     1020 non-null   object
#  1   Age            1020 non-null   int64
#  2   Gender         1020 non-null   object
#  3   Study_Hours    989 non-null    float64
#  4   Attendance(%)  990 non-null    float64
#  5   Test_Score     1020 non-null   float64
#  6   Grade          1011 non-null   object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 55.9+ KB

# %%
df.describe()
# Out:
#                Age  Study_Hours  Attendance(%)   Test_Score
# count  1020.000000   989.000000     990.000000  1020.000000
# mean     20.970588     5.160768      84.871919    49.843137
# std       2.008109     2.555877      10.007239    21.278630
# min      18.000000    -2.000000      50.300000     0.000000
# 25%      19.000000     3.700000      78.000000    35.000000
# 50%      21.000000     5.100000      85.000000    50.000000
# 75%      23.000000     6.300000      91.975000    64.000000
# max      24.000000    25.000000     115.600000   100.000000

# %% [markdown]
# # check the null or  missing value

# %%
df.isnull().sum()
# Out:
# Student_ID        0
# Age               0
# Gender            0
# Study_Hours      31
# Attendance(%)    30
# Test_Score        0
# Grade             9
# dtype: int64

# %%
(df.isnull().sum()/len(df))*100
# Out:
# Student_ID       0.000000
# Age              0.000000
# Gender           0.000000
# Study_Hours      3.039216
# Attendance(%)    2.941176
# Test_Score       0.000000
# Grade            0.882353
# dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(),
            cbar=False,
            cmap="coolwarm")
plt.title(" Missing Values Heatmap ")
plt.show()

# %% [markdown]
# # Missing values were identified to understand data quality issues before analysis.

# %% [markdown]
# # check the duplicates

# %%
df.duplicated().sum()
# Out:
# np.int64(20)

# %%
df[df.duplicated()]
# Out:
#     Student_ID  Age  Gender  Study_Hours  Attendance(%)  Test_Score Grade
# 136      S0137   24    Male          2.9           83.6        48.0     F
# 278      S0762   23    Male          5.7           78.8        53.0     C
# 410      S0812   18    Male          5.4           84.5        66.0     B
# 434      S0939   23    Male          5.5           74.9        48.0     F
# 445      S0679   21    Male          8.3           81.1        85.0     A
# 506      S0627   18    Male          6.6           93.1        76.0     B
# 517      S0900   18  Female          0.4          115.6         1.0     F
# 529      S0661   18  Female          3.4           63.6        29.0     F
# 559      S0077   23    Male          6.5           87.4        70.0     B
# 573      S0320   24  Female          8.1           79.0        79.0     B
# 633      S0412   22    Male          NaN          104.8        49.0     F
# 696      S0884   22  Female          6.6           95.8        84.0     A
# ...

# %%
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()
# Out:
# Student_ID        0
# Age               0
# Gender            0
# Study_Hours      30
# Attendance(%)    30
# Test_Score        0
# Grade             8
# dtype: int64

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Student_ID, Age, Gender, Study_Hours, Attendance(%), Test_Score, Grade]
# Index: []

# %% [markdown]
# # check the size columns and rows

# %%
df.shape
# Out:
# (1000, 7)

# %%
df.columns
# Out:
# Index(['Student_ID', 'Age', 'Gender', 'Study_Hours', 'Attendance(%)',
#        'Test_Score', 'Grade'],
#       dtype='object')

# %%
df['Study_Hours'].unique()
# Out:
# array([ 2.7,  1.5,  6.8,  6.2,  7.4,  4. ,  5.1,  5.7,  6.5,  nan,  5.5,
#         4.5,  3.6,  7.2,  3.3,  2. ,  5.6,  7.1,  5.9,  5.3,  4.3,  6.9,
#         4.9,  6. ,  7.8,  2.8,  3.7,  4.7,  8.3,  3.9,  7. ,  4.4,  9. ,
#         3.1,  4.8,  8.6,  1.2,  4.6,  5. ,  0.8,  6.1, 20. ,  3.2,  7.3,
#         1.1,  5.4,  7.6,  9.3,  6.6,  0.4,  1.6,  4.2,  6.4,  1.8,  2.9,
#         8. , 10.5,  9.1,  3.5,  1.4,  0.6,  0.5,  8.4,  3.4,  7.9,  2.5,
#         1.9,  3.8,  8.1, 10.9,  6.7,  5.8, -2. ,  2.4,  5.2, 25. ,  2.3,
#         4.1,  1.3,  8.5,  3. ,  7.5,  6.3,  2.2,  9.2,  8.2,  7.7,  2.6,
#        10.4,  8.8,  1.7,  8.9,  8.7,  9.6,  2.1,  9.7,  9.4,  0. , -0.5,
#         0.9,  0.7,  9.8,  9.9, -0.8, -0.7,  0.2, 10.3])

# %%
df['Attendance(%)'].unique()
# Out:
# array([ 74. ,  93.1,  97.2,  93.5,  99.2,  68.8,  77.7,  97.4,  87.4,
#        104.8, 100. ,  94. ,  90.2,  80.2,  91.4,  87.6,  83.2,  79.5,
#         83.3,  82.3,  83. ,   nan,  70.8,  85.4,  95. ,  71.9,  80.3,
#         72. ,  69.7,  81.1,  87.1,  88.3,  84.7,  89.2,  90.7,  72.1,
#         90.4,  96.1,  81.7,  89.5,  95.5,  80.6,  85.2,  78.8,  73.2,
#         86.5,  90.1,  76.8,  82.6,  61.7,  82.8,  99.6,  78. , 103. ,
#         94.6,  89.7,  68.3,  78.3,  70.9,  78.5,  81. ,  82.5,  88.4,
#         96.6,  78.6,  70.7,  66.1,  74.4,  95.4,  69.6,  96.5,  75.5,
#         83.1,  75.9, 107.2,  71.4,  89.9,  92.6,  98.4,  91.8,  85.1,
#         84.3,  73.3,  79.3,  65.4, 106.9,  84.8,  95.7,  94.8,  85. ,
#         73.5,  87.9,  80.4,  88.2,  72.9,  86.9,  78.1,  78.4,  74.8,
#         83.6,  84.5,  88.8,  90.8, 101.7, 100.8,  81.9,  83.5,  63.6,
#         85.7,  86.1,  82.9, 115.6,  97.1,  73.9,  80.1,  67. ,  98.9,
# ...

# %%
df['Grade'].unique()
# Out:
# array(['F', 'A', 'C', 'B', 'A+', nan], dtype=object)

# %% [markdown]
# # Analysis the data where we get nan so now fillnan by using mean median and mode which one suitable for what

# %% [markdown]
# # Study_Hours

# %%
df['Study_Hours'].unique()
# Out:
# array([ 2.7,  1.5,  6.8,  6.2,  7.4,  4. ,  5.1,  5.7,  6.5,  nan,  5.5,
#         4.5,  3.6,  7.2,  3.3,  2. ,  5.6,  7.1,  5.9,  5.3,  4.3,  6.9,
#         4.9,  6. ,  7.8,  2.8,  3.7,  4.7,  8.3,  3.9,  7. ,  4.4,  9. ,
#         3.1,  4.8,  8.6,  1.2,  4.6,  5. ,  0.8,  6.1, 20. ,  3.2,  7.3,
#         1.1,  5.4,  7.6,  9.3,  6.6,  0.4,  1.6,  4.2,  6.4,  1.8,  2.9,
#         8. , 10.5,  9.1,  3.5,  1.4,  0.6,  0.5,  8.4,  3.4,  7.9,  2.5,
#         1.9,  3.8,  8.1, 10.9,  6.7,  5.8, -2. ,  2.4,  5.2, 25. ,  2.3,
#         4.1,  1.3,  8.5,  3. ,  7.5,  6.3,  2.2,  9.2,  8.2,  7.7,  2.6,
#        10.4,  8.8,  1.7,  8.9,  8.7,  9.6,  2.1,  9.7,  9.4,  0. , -0.5,
#         0.9,  0.7,  9.8,  9.9, -0.8, -0.7,  0.2, 10.3])

# %% [markdown]
# # Using median for Study_Hours because the distribution is skewed (mean affected by outliers)

# %%
df['Study_Hours'] = df['Study_Hours'].fillna(df['Study_Hours'].median())

# %% [markdown]
# # remove the  negative datasets

# %%
df = df[df['Study_Hours'] >= 0]

# %%
df['Study_Hours'].unique()
# Out:
# array([ 2.7,  1.5,  6.8,  6.2,  7.4,  4. ,  5.1,  5.7,  6.5,  5.5,  4.5,
#         3.6,  7.2,  3.3,  2. ,  5.6,  7.1,  5.9,  5.3,  4.3,  6.9,  4.9,
#         6. ,  7.8,  2.8,  3.7,  4.7,  8.3,  3.9,  7. ,  4.4,  9. ,  3.1,
#         4.8,  8.6,  1.2,  4.6,  5. ,  0.8,  6.1, 20. ,  3.2,  7.3,  1.1,
#         5.4,  7.6,  9.3,  6.6,  0.4,  1.6,  4.2,  6.4,  1.8,  2.9,  8. ,
#        10.5,  9.1,  3.5,  1.4,  0.6,  0.5,  8.4,  3.4,  7.9,  2.5,  1.9,
#         3.8,  8.1, 10.9,  6.7,  5.8,  2.4,  5.2, 25. ,  2.3,  4.1,  1.3,
#         8.5,  3. ,  7.5,  6.3,  2.2,  9.2,  8.2,  7.7,  2.6, 10.4,  8.8,
#         1.7,  8.9,  8.7,  9.6,  2.1,  9.7,  9.4,  0. ,  0.9,  0.7,  9.8,
#         9.9,  0.2, 10.3])

# %% [markdown]
# # Attendance(%)

# %%
df['Attendance(%)'].unique()
# Out:
# array([ 74. ,  93.1,  97.2,  93.5,  99.2,  68.8,  77.7,  97.4,  87.4,
#        104.8, 100. ,  94. ,  90.2,  80.2,  91.4,  87.6,  83.2,  79.5,
#         83.3,  82.3,  83. ,   nan,  70.8,  85.4,  95. ,  71.9,  80.3,
#         72. ,  69.7,  81.1,  87.1,  88.3,  84.7,  89.2,  90.7,  72.1,
#         90.4,  96.1,  81.7,  89.5,  95.5,  80.6,  85.2,  78.8,  73.2,
#         86.5,  90.1,  76.8,  82.6,  61.7,  82.8,  99.6,  78. , 103. ,
#         94.6,  89.7,  68.3,  78.3,  70.9,  78.5,  81. ,  82.5,  88.4,
#         96.6,  78.6,  70.7,  66.1,  74.4,  95.4,  69.6,  96.5,  75.5,
#         83.1,  75.9, 107.2,  71.4,  89.9,  92.6,  98.4,  91.8,  85.1,
#         84.3,  73.3,  79.3,  65.4, 106.9,  84.8,  95.7,  94.8,  85. ,
#         73.5,  87.9,  80.4,  88.2,  72.9,  86.9,  78.1,  78.4,  74.8,
#         83.6,  84.5,  88.8,  90.8, 101.7, 100.8,  81.9,  83.5,  63.6,
#         85.7,  86.1,  82.9, 115.6,  97.1,  73.9,  80.1,  67. ,  98.9,
# ...

# %%
df = df[df['Attendance(%)'] >= 0]

# %%
df['Attendance(%)'] = df['Attendance(%)'].fillna(df['Attendance(%)'].median())

# %%
df['Attendance(%)'].unique()
# Out:
# array([ 74. ,  93.1,  97.2,  93.5,  99.2,  68.8,  77.7,  97.4,  87.4,
#        104.8, 100. ,  94. ,  90.2,  80.2,  91.4,  87.6,  83.2,  79.5,
#         83.3,  82.3,  83. ,  70.8,  85.4,  95. ,  71.9,  80.3,  72. ,
#         69.7,  81.1,  87.1,  88.3,  84.7,  89.2,  90.7,  72.1,  90.4,
#         96.1,  81.7,  89.5,  95.5,  80.6,  85.2,  78.8,  73.2,  86.5,
#         90.1,  76.8,  82.6,  61.7,  82.8,  99.6,  78. , 103. ,  94.6,
#         89.7,  68.3,  78.3,  70.9,  78.5,  81. ,  82.5,  88.4,  96.6,
#         78.6,  70.7,  66.1,  74.4,  95.4,  69.6,  96.5,  75.5,  83.1,
#         75.9, 107.2,  71.4,  89.9,  92.6,  98.4,  91.8,  85.1,  84.3,
#         73.3,  79.3,  65.4, 106.9,  84.8,  95.7,  94.8,  85. ,  73.5,
#         87.9,  80.4,  88.2,  72.9,  86.9,  78.1,  78.4,  74.8,  83.6,
#         84.5,  88.8,  90.8, 101.7, 100.8,  81.9,  83.5,  63.6,  85.7,
#         86.1,  82.9, 115.6,  97.1,  73.9,  80.1,  67. ,  98.9,  99.4,
# ...

# %% [markdown]
# # Grade

# %%
df['Grade'].unique()
# Out:
# array(['F', 'A', 'C', 'B', 'A+', nan], dtype=object)

# %%
df['Grade'] = df['Grade'].fillna(df['Grade'].mode()[0])

# %%
df['Grade'].unique()
# Out:
# array(['F', 'A', 'C', 'B', 'A+'], dtype=object)

# %% [markdown]
# # Data Visualization

# %% [markdown]
# # Histograms

# %%
numeric_cols = [ 'Study_Hours', 'Attendance(%)', 'Test_Score']

for col in numeric_cols:
    plt.figure(figsize=(6,4))
    sns.histplot(df[col], kde=True)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel("Frequency")
    plt.show()

# %% [markdown]
# # Bar Chart

# %%
df['Grade'].value_counts().plot(kind='bar')

plt.title('Distribution of Grades')
plt.xlabel('Grade')
plt.ylabel('Number of Students')
plt.show()

# %% [markdown]
# # Box Plot
#
# Test Score Outliers

# %%
sns.boxplot(x=df['Test_Score'])
plt.title('Box Plot of Test Scores')
plt.show()

# %% [markdown]
# # Test Score by Gender

# %%
sns.boxplot(x='Gender', y='Test_Score', data=df)

plt.title('Test Score by Gender')
plt.show()

# %% [markdown]
# # Scatter Plot

# %% [markdown]
# #
# Study Hours vs Test Score

# %%
sns.scatterplot(
    x='Study_Hours',
    y='Test_Score',
    data=df
)

plt.title('Study Hours vs Test Score')
plt.show()

# %% [markdown]
# # Attendance vs Test Score

# %%
sns.scatterplot(
    x='Attendance(%)',
    y='Test_Score',
    data=df
)

plt.title('Attendance vs Test Score')
plt.show()

# %% [markdown]
# #  Correlation Heatmap

# %%
numeric_df = df[['Age', 'Study_Hours', 'Attendance(%)', 'Test_Score']]

sns.heatmap(
    numeric_df.corr(),
    annot=True,
    cmap='coolwarm'
)

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# #

# %% [markdown]
# # Descriptive Statistics

# %%
df[['Age', 'Study_Hours', 'Attendance(%)', 'Test_Score']].describe()
# Out:
#               Age  Study_Hours  Attendance(%)  Test_Score
# count  966.000000   966.000000     966.000000  966.000000
# mean    20.978261     5.191822      84.866667   49.953416
# std      1.989752     2.523010       9.938779   21.016867
# min     18.000000     0.000000      50.300000    0.000000
# 25%     19.000000     3.700000      78.000000   35.000000
# 50%     21.000000     5.100000      85.050000   49.500000
# 75%     23.000000     6.300000      91.975000   64.000000
# max     24.000000    25.000000     115.600000  100.000000

# %% [markdown]
# The mean (average) test score is approximately 50, while the mean study hours are about 5.2 hours per day and mean attendance is nearly 85%. These values represent the central tendency of the data, showing typical student behavior and performance.

# %% [markdown]
# # Mode

# %%
df[['Age', 'Study_Hours', 'Attendance(%)', 'Test_Score']].mode()
# Out:
#    Age  Study_Hours  Attendance(%)  Test_Score
# 0   21          5.1           90.4        49.0

# %% [markdown]
# The mode for study hours is 5.1 hours, meaning this is the most frequently reported study duration among students. For test scores, the mode is 49, which aligns closely with both the mean and median.

# %% [markdown]
# # Variance

# %%
df[['Age', 'Study_Hours', 'Attendance(%)', 'Test_Score']].var()
# Out:
# Age                3.959112
# Study_Hours        6.365581
# Attendance(%)     98.779323
# Test_Score       441.708709
# dtype: float64

# %% [markdown]
# Test scores show a high variance of 441.7, indicating student performance varies widely across the dataset. Study hours have moderate variance (6.37), while attendance shows relatively lower variance (98.8) compared to test scores.

# %% [markdown]
# # Median

# %%
df[['Age', 'Study_Hours', 'Attendance(%)', 'Test_Score']].median()
# Out:
# Age              21.00
# Study_Hours       5.10
# Attendance(%)    85.05
# Test_Score       49.50
# dtype: float64

# %% [markdown]
# The median test score is 49.5, very close to the mean of 50, indicating the score distribution is roughly symmetric without significant skew. The median study hours (5.1) and median attendance (85.05%) are also nearly identical to their means.

# %% [markdown]
# # Standard Deviation

# %%
df[['Age', 'Study_Hours', 'Attendance(%)', 'Test_Score']].std()
# Out:
# Age               1.989752
# Study_Hours       2.523010
# Attendance(%)     9.938779
# Test_Score       21.016867
# dtype: float64

# %% [markdown]
# The standard deviation for test scores is 21.0, meaning most students' scores fall within approximately 30 to 70 points . Study hours have a standard deviation of 2.5 hours, while attendance varies by about 10 percentage points.

# %% [markdown]
# # IQR

# %%
Q1 = df[['Age', 'Study_Hours', 'Attendance(%)', 'Test_Score']].quantile(0.25)
Q3 = df[['Age', 'Study_Hours', 'Attendance(%)', 'Test_Score']].quantile(0.75)

IQR = Q3 - Q1

print(IQR)
# Out:
# Age               4.000
# Study_Hours       2.600
# Attendance(%)    13.975
# Test_Score       29.000
# dtype: float64

# %% [markdown]
# The interquartile range (IQR) for test scores is 29 points (from 35 to 64), showing the middle 50% of students performed within this narrower band. This helps identify that the wide overall variance comes mainly from the lowest and highest scoring students.

# %% [markdown]
# # Hypothesis Formulation and Statistical Testing

# %% [markdown]
# # Research Question
# Does study time affect student performance?

# %% [markdown]
# # Null Hypothesis (H₀)
# There is no significant relationship between Study Hours and Test Score.

# %% [markdown]
# # Alternative Hypothesis (H₁)
# There is a significant positive relationship between Study Hours and Test Score.

# %% [markdown]
# # Correlation Test

# %%
from scipy.stats import pearsonr

corr, p_value = pearsonr(df['Study_Hours'], df['Test_Score'])

print("Correlation coefficient:", corr)
print("P-value:", p_value)
# Out:
# Correlation coefficient: 0.6452397151105683
# P-value: 7.772744007759827e-115

# %% [markdown]
# # Interpretation
# Correlation Coefficient (r = 0.6452)
# The correlation value is positive. It is moderately strong, indicating a clear positive relationship between Study Hours and Test Score. As students spend more time studying, their test scores generally increase.

# %% [markdown]
# # P-value (7.77e-115)
#
# The p-value is far less than 0.05. Therefore, the result is statistically significant.

# %% [markdown]
# # Conclusion
#
# Since the p-value < 0.05, we reject the Null Hypothesis (H₀) and accept the Alternative Hypothesis (H₁). This means there is a statistically significant positive relationship between Study Hours and Test Score.
